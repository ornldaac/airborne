# %% [markdown]
# # SC 16 - Plot to Plane: Working with NASA and NEON Airborne and Field Datasets
#
# ### Ecological Society of America 2025 Conference In-Person Short Course
#
# #### SC 16 - Plot to Plane: Working with NASA and NEON Airborne and Field Datasets
# **Friday, August 15, 2025 - 8:00 AM – 11:00 AM EDT:**
#
# The contents of this tutorial were presented at an in-person Short Course held at the Ecological Society of America (ESA) 2025 Conference in Baltimore, Maryland.  Short Course participants had live coding experience within a Managed JupyterHub Service, supported by [2i2c](https://2i2c.org/) and by the [NASA Openscapes Community](https://nasa-openscapes.github.io/).

# %% [markdown]
# # Tutorial:  NASA Earthdata Search and Discovery of Airborne AVIRIS Data

# %% [markdown]
# **Summary**
#
# This notebook will demonstrate how to search, discover, subset, and access NASA airborne imaging spectrometer data derived from the AVIRIS (Airborne Visible / Infrared Imaging Spectrometers) suite of instruments.  AVIRIS data are archived to NASA Earthdata collections, but but given the many years of flights in support of varied NASA campaigns, can be a challenge to discover and access.
#
# The `earthaccess` Python library simplifies programmatic discovery and access of NASA Earthdata data including the many AVIRIS instrument's radiance, reflectance, and further derived campaign data.  `earthaccess` is a useful Python library that facilitates finding and downloading or streaming data over HTTPS or s3. earthaccess searches NASA's Common Metadata Repository (CMR) which is a metadata system that catalogs Earth Science data and associated metadata records.  This can then be used to download granules or generate lists of granule search result URLs.
#
# With areas and times of interest identified, flight metadata will be used to build and visual flight paths within those subset parameters.

# %% [markdown]
# **Background**
#
# Developed at the NASA Jet Propulsion Laboratory (JPL), the Airborne Visible / Infrared Imaging Spectrometers (AVIRIS) are a unique suite of optical sensors that collect data while mounted on [airborne platforms](https://airbornescience.nasa.gov/aircraft) such as the B200 LARC or an ER-2 AFRC.  Imaging spectrometers collect light reflected off of an object (the Earth in this case) and then analyze the intensity of the wavelengths present at each pixel. As their names suggest, the AVIRIS instruments collect light in the visible to infrared wavelenths.
# These data can be used for characterization of the Earth's surface and atmosphere and applied to studies in the fields of oceanography, environmental science, snow hydrology, geology, volcanology, soil and land management, atmospheric and aerosol studies, agriculture, and limnology.
#
# >Green, R.O., M.L. Eastwood, C.M. Sarture, T. G. Chrien, M. Aronsson, B.J. Chippendale, J.A. Faust, B.E. Pavri, C. J. Chovit, M. Solis, M.R. Olah, and O. Williams. 1998. Imaging Spectroscopy and the Airborne Visible/Infrared Imaging Spectrometer (AVIRIS). Remote Sensing of Environment 65:227- 248. https://doi.org/10.1016/S0034-4257(98)00064-9
# >
# >Chadwick KD, Brodrick PG, Grant K, et al. Integrating airborne remote sensing and field campaigns for ecology and Earth system science. Methods Ecol Evol. 2020; 11: 1492–1508. https://doi.org/10.1111/2041-210X.13463
#
#
# ![AVIRIS](images/AVIRIS_suiteFIs_cube2.PNG)
#
# AVIRIS imaging spectrometers break down light into hundreds of narrow spectral bands, providing a spectrum for each point (or pixel) in the image.  The resulting data are typically stored in a 3-dimensional array sometimes referred to as a data cube.  The x and y dimensions represent the spatial dimensions of the image and the z dimension represents the wavelength information. JPL processes and provides data as radiance (L1B) and reflectance (L2A) which are archived and publically available through NASA Earthdata Facility Instrument Collections.  These data files are historically distributed in a popular remote sensing ENVI file format and more recently as a standardized netCDF file format.
#
# **AVIRIS Data Processing Levels**
# - L1B - Resampled calibrated data in units of spectral **radiance** as well as observational geometry and illumination parameters
# - L2 - Calibrated Reflectance
# - L2A - Orthocorrected and atmospherically corrected **reflectance** data
# - L2B - Enhanced Surface Reflectance which can include topographic, glint, and bidirectional reflectance distribution function (BRDF) corrections
# - L3 - Variables are mapped on uniform space-time grid scales, usually with some completeness and consistency.
#
# [**NASA Earthdata AVIRIS Project Data**](https://www.earthdata.nasa.gov/data/projects/aviris/data-access-tools)
# **`Facility Instrument`** Links
# - [AVIRIS-Classic: L1B Calibrated Radiance, Facility Instrument Collection, V1](https://www.earthdata.nasa.gov/data/catalog/ornl-cloud-aviris-classic-l1b-radiance-2155-1)
# - [AVIRIS-Classic: L2 Calibrated Reflectance, Facility Instrument Collection, V1](https://www.earthdata.nasa.gov/data/catalog/ornl-cloud-aviris-classic-l2-reflectance-2154-1)
# - [AVIRIS-NG L1B Calibrated Radiance, Facility Instrument Collection, V1](https://www.earthdata.nasa.gov/data/catalog/ornl-cloud-aviris-ng-l1b-radiance-2095-1)
# - [AVIRIS-NG L2 Surface Reflectance, Facility Instrument Collection, V1](https://www.earthdata.nasa.gov/data/catalog/ornl-cloud-aviris-ng-l2-reflectance-2110-1)
# - [AVIRIS-3 L1B Calibrated Radiance, Facility Instrument Collection](https://www.earthdata.nasa.gov/data/catalog/ornl-cloud-av3-l1b-rdn-2356-1)
# - [AVIRIS-3 L2A Orthocorrected Surface Reflectance, Facility Instrument Collection](https://www.earthdata.nasa.gov/data/catalog/ornl-cloud-av3-l2a-rfl-2357-1)

# %% [markdown]
# **Notebook Requirements**
#
# A NASA [Earthdata Login](https://urs.earthdata.nasa.gov/users/new) account is required

# %% [markdown]
# **Learning Objectives**
# - login and authenticate to NASA Earthdata Login using **earthaccess**
# - construct searches of the NASA Common Metadata Repository (CMR) for specific airborne instruments
# - construct searches of the NASA Common Metadata Repository (CMR) for specific NASA Projects/Campaigns
# - narrow a search of the CMR to for files from AVIRIS instrument flights based on a spatial area of interest
# - programmatically discover specific AVIRIS- file access URLs based on metadata and spatial/temporal parameters
# - create flight line bounding boxes from a search result using CMR file(granule)-level metadata

# %% [markdown]
# ## Set Up
#
# Import the required Python libraries

# %%
import earthaccess
import geopandas as gpd
import pyproj
from pyproj import Proj
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from shapely.ops import transform
from shapely.ops import orient
from shapely.geometry import Polygon, MultiPolygon
import folium

# %% [markdown]
# ![earthaccess](images/earthaccess_rs.png)
#
# [**`earthaccess`**](https://www.earthdata.nasa.gov/news/blog/earthaccess-earth-science-data-simplifiedl) is a Python library that simplifies data discovery and access to NASA Earthdata data by providing an abstraction layer to NASA's APIs for programmatic access.
#
# earthaccess will be used to:
# - **`Authentication:`** - handles a user's identity (authentication) with NASA's Earthdata Login (EDL),
# - **`Search:`** search the NASA Earthdata Data holdings using NASA's Common Metadata Repository (CMR), and
# - **`Access:`** provide direct cloud file download and access
#
# **Earthdata Login**
#
# NASA [**`Earthdata Login`**](https://urs.earthdata.nasa.gov/)  is a user registration and profile management system for users getting Earth science data from NASA Earthdata.  If you download or access NASA Earthdata data, you need an Earthdata Login.

# %% [markdown]
# ## Authentication

# %% [markdown]
# Using `earthaccess` we'll login and **authenticate** to NASA Systems.
# - For this exercise, we will be prompted for and interactively enter our Eathdata Login credentials (login, password)

# %%
auth = earthaccess.login()

# %% [markdown]
# ## Searching by **Collection**
#
# The **earthaccess** `search_datasets` function with the `keyword` argument can be used to search collections.
#
# Given the many Instruments and Campaigns, there are several AVIRIS-* collections or datasets available within the NASA Earthdata cloud archive.

# %%
# Retrieve Collections
collections = earthaccess.search_datasets(keyword='AVIRIS')
# Print Quantity of Results
print(f'Collections found: {len(collections)}')
# Out:
# Collections found: 96

# %% [markdown]
# Printing the collections object explores all of the json metadata.

# %%
#Print collections
#printing the first index
#collections[0]

# %% [markdown]
# We can create a list of the **short-name**, **concept-id**, version, and **EntryTitle** of each result collection using list comprehension. These fields are important for specifying and searching for data within collections.

# %%
collections_info = [
    {
        'short_name': c.summary()['short-name'],
        'collection_concept_id': c.summary()['concept-id'],
        'version': c.summary()['version'],
        'entry_title': c['umm']['EntryTitle']
    }
    for c in collections
]
pd.set_option('display.max_colwidth', 150)
collections_info = pd.DataFrame(collections_info)
collections_info
# Out:
#                             short_name   collection_concept_id version  \
# 0       AVIRIS_FlightLine_Locator_2140  C2662360177-ORNL_CLOUD     1.0
# 1   AVIRIS-Classic_L2_Reflectance_2154  C2711871294-ORNL_CLOUD       1
# 2     AVIRIS-Classic_L1B_Radiance_2155  C2714723060-ORNL_CLOUD       1
# 3     WDTS_AVIRIS-C_foliar_traits_2403  C3559165097-ORNL_CLOUD       1
# 4      WDTS_AVIRIS-C_L2_corrected_2391  C3472608710-ORNL_CLOUD       1
# ..                                 ...                     ...     ...
# 91                      SARP_2010_Data  C3352893542-LARC_CLOUD       1
# 92                      SARP_2009_Data  C3354318227-LARC_CLOUD       1
# 93                        rss18opt_503  C2808092274-ORNL_CLOUD       1
# 94                         rss4lib_292  C2807643026-ORNL_CLOUD       1
# 95                        plotchem_420  C2776829507-ORNL_CLOUD       1
#
#                                                                            entry_title
# 0              AVIRIS Facility Instruments: Flight Line Geospatial and Contextual Data
# 1        AVIRIS-Classic: L2 Calibrated Reflectance, Facility Instrument Collection, V1
# 2          AVIRIS-Classic: L1B Calibrated Radiance, Facility Instrument Collection, V1
# 3                          WDTS: AVIRIS-Classic Derived Plant Trait Mosaics, 2013-2018
# 4   WDTS: AVIRIS-Classic L2B Corrected and Georectified Surface Reflectance, 2013-2018
# ..                                                                                 ...
# 91                                                                      SARP 2010 Data
# 92                                                                      SARP 2009 Data
# 93                                       BOREAS RSS-18 Sunphotometer Data over the SSA
# 94      BOREAS RSS-04 1994 Jack Pine Leaf Biochemistry and Modeled Spectra in the SSA
# 95                                   Calculated Leaf Carbon and Nitrogen, 1992 (ACCP)
#
# [96 rows x 4 columns]

# %% [markdown]
# ## Searching by **Instrument**

# %%
#instrument = earthaccess.search_datasets(instrument="AVIRIS-3")
instrument = earthaccess.search_datasets(instrument="AVIRIS-NG")
#instrument = earthaccess.search_datasets(instrument="AVIRIS") # AVIRIS-Classic
print(f"Total Datasets (instrument) found: {len(instrument)}")
# Out:
# Total Datasets (instrument) found: 30

# %%
instrument_info = [
    {
        'short_name': i.summary()['short-name'],
        'collection_concept_id': i.summary()['concept-id'],
        'version': i.summary()['version'],
        'entry_title': i['umm']['EntryTitle']
    }
    for i in instrument
]
pd.set_option('display.max_colwidth', 150)
instrument_info = pd.DataFrame(instrument_info)
instrument_info
# Out:
#                              short_name   collection_concept_id version  \
# 0   BioSCape_ANG_V02_L3_RFL_Mosaic_2427  C3523930138-ORNL_CLOUD       2
# 1      ABoVE_Airborne_AVIRIS_NG_V3_2362  C3253178409-ORNL_CLOUD       3
# 2         AVIRIS-NG_CH4_CO2_Plumes_2406  C3583710513-ORNL_CLOUD       1
# 3             AVIRIS-NG_Data_Idaho_1533  C2765511853-ORNL_CLOUD       1
# 4           AVIRIS-NG_L1B_radiance_2095  C2662359874-ORNL_CLOUD       1
# 5         AVIRIS-NG_L2_Reflectance_2110  C2659129205-ORNL_CLOUD       1
# 6        AVIRIS_FlightLine_Locator_2140  C2662360177-ORNL_CLOUD     1.0
# 7      BioSCape_AVNG_L2B_BRDF_GCFR_2385  C3567037541-ORNL_CLOUD       1
# 8              CH4_Plume_AVIRIS-NG_1727  C2389764676-ORNL_CLOUD       1
# 9          COMEX_AVIRIS_NG_Flights_2342  C3103969015-ORNL_CLOUD       1
# 10  DeltaX_AVIRIS-NG_UAVSAR_L3_AGB_2410  C3556516287-ORNL_CLOUD       1
# 11       DeltaX_L1_AVIRIS_Radiance_1987  C2256471725-ORNL_CLOUD       1
# 12    DeltaX_L2A_AVIRIS-NG_BRDF_V3_2355  C3397061771-ORNL_CLOUD       3
# 13  DeltaX_L2B_AVIRIS-NG_FracCover_2407  C3567238741-ORNL_CLOUD       1
# 14    DeltaX_L2_AVIRIS_Reflectance_1988  C2430019879-ORNL_CLOUD       1
# 15      DeltaX_L3_AVIRIS-NG_AGB_V3_2409  C3580020915-ORNL_CLOUD       3
# 16   DeltaX_L3_AVIRIS-NG_Veg_Types_2352  C3255110465-ORNL_CLOUD       1
# 17    DeltaX_L3_AVIRIS-NG_Water_V3_2152  C2797469962-ORNL_CLOUD       3
# 18          PreDeltaX_L2_AVIRIS_SR_1826  C2025126944-ORNL_CLOUD       1
# 19     PreDeltaX_L3_AVIRIS_Biomass_1821  C2025126705-ORNL_CLOUD       1
# 20    PreDeltaX_L3_AVIRIS_Sediment_1822  C2025126777-ORNL_CLOUD       1
# 21         SHIFT_AVIRISNG_L2A_refl_2376  C3255170754-ORNL_CLOUD       1
# 22  SHIFT_AVNG_Canopy_WaterContent_2242  C2755452168-ORNL_CLOUD       1
# 23       SHIFT_AVNG_FullRes_QkLook_2189  C2844912911-ORNL_CLOUD       1
# 24        SHIFT_AVNG_L1A_RDN_unrec_2184  C2769459290-ORNL_CLOUD       1
# 25          SHIFT_Wetland_Salinity_2436  C3596524160-ORNL_CLOUD       1
# 26                           SNEX21_SSR  C3274546970-NSIDC_CPRD       1
# 27                SNEX23_Apr23_AVIRISNG  C3401825738-NSIDC_CPRD       1
# 28   Wetland_VegClassification_PAD_2069  C2308233855-ORNL_CLOUD       1
# 29                     goesrpltavirisng   C1995568884-GHRC_DAAC       1
#
#                                                                                              entry_title
# 0                                               BioSCape: AVIRIS-NG L3 Resampled Reflectance Mosaics, V2
# 1                   ABoVE: AVIRIS-NG Imaging Spectroscopy for Alaska, Canada, and Iceland, 2017-2022, V3
# 2                                        STAQS AVIRIS-NG-derived Methane and Carbon Dioxide Plumes, 2023
# 3                        Hyperspectral Imagery from AVIRIS-NG for Sites in ID and CA, USA, 2014 and 2015
# 4                                  AVIRIS-NG L1B Calibrated Radiance, Facility Instrument Collection, V1
# 5                                   AVIRIS-NG L2 Surface Reflectance, Facility Instrument Collection, V1
# 6                                AVIRIS Facility Instruments: Flight Line Geospatial and Contextual Data
# 7                                                   BioSCape: AVIRIS-NG L2B Enhanced Surface Reflectance
# 8                  Methane Plumes Derived from AVIRIS-NG over Point Sources across California, 2016-2017
# 9                          COMEX: AVIRIS-NG Facility Instrument Associated Flights and Information, 2014
# 10                           Delta-X AVIRIS-NG and UAVSAR L3 Derived Forest Aboveground Biomass, MRD, LA
# 11                               Delta-X: AVIRIS-NG L1B Spectral Radiance Products, MRD, Louisiana, 2021
# 12                   Delta-X: AVIRIS-NG BRDF-Adjusted Surface Reflectance and Mosaics, MRD, LA, 2021, V3
# 13                                   Delta-X: AVIRIS-NG L2B Derived Fractional Cover, MRD, LA, USA, 2021
# 14                                        Delta-X: AVIRIS-NG L2 Surface Reflectance, MRD Louisiana, 2021
# 15                 Delta-X: AVIRIS-NG L3 Derived Herbaceous Aboveground Biomass, MRD, Louisiana, USA, V3
# 16                                    Delta-X AVIRIS-NG L3 Derived Vegetation Types, MRD, Louisiana, USA
# 17                              Delta-X: AVIRIS-NG L3-derived Water Quality, TSS, and Turbidity, MRD, V3
# 18                 Pre-Delta-X: L2 AVIRIS-NG Surface Spectral Reflectance across MRD, LA, USA, 2015-2016
# 19                   Pre-Delta-X: Aboveground Biomass and Vegetation Maps, Wax Lake Delta, LA, USA, 2016
# 20                   Pre-Delta-X: AVIRIS-derived Total Suspended Solids Maps for MRD, LA, USA, 2015-2016
# 21                                        SHIFT: AVIRIS-NG L2A Unrectified Surface Reflectance Version 1
# 22                     SHIFT: AVIRIS-NG Derived Gridded Mosaicked Canopy Water Content, California, 2022
# 23                                                    SHIFT: AVIRIS-NG Full-Resolution True Color Images
# 24                                                             SHIFT: AVIRIS-NG L1A Unrectified Radiance
# 25                     SHIFT: Wetland Spectra, Salinity, and Fractional Cover, Devereux Slough, CA, 2022
# 26            SnowEx21 Senator Beck Basin and Grand Mesa, CO AVIRIS-NG Surface Spectral Reflectance V001
# 27                                            SnowEx23 Apr23 AVIRIS-NG Surface Spectral Reflectance V001
# 28                      ABoVE: Wetland Vegetation Classification for Peace-Athabasca Delta, Canada, 2019
# 29  GOES-R PLT Field Campaign Airborne Visible/Infrared Imaging Spectrometer Next Generation (AVIRIS-NG)

# %% [markdown]
# The collection `concept-id` or `short_name` are unique to each collection. After finding the collection you want to search, you can use the short_name or concept-id to search for granules (or files) within that collection.

# %% [markdown]
# ## Searching by **Project**

# %%
results = earthaccess.search_datasets(project="BioSCape")
#results = earthaccess.search_datasets(project="ABoVE")
print(f"Total Datasets (results_projects) found: {len(results)}")
# Out:
# Total Datasets (results_projects) found: 11

# %%
for item in results:
    summary = item.summary()
    print(summary["short-name"])
# Out:
# BioSCape_ANG_V02_L3_RFL_Mosaic_2427
# Acoustic_Data_Cape_Floristic_2372
# BIOSCAPE_COASTAL_CARBON
# BioSCape_AVNG_L2B_BRDF_GCFR_2385
# BioSCape_VegPlots_Berg_Eerste_2425
# LVISF1B
# LVISF1B
# LVISF2
# LVISF2
# OLVIS1A
# OLVIS1A

# %% [markdown]
# ## Search AVIRIS-3 Instrument (only) for Specific Project/Campaign

# %% [markdown]
# - AVIRIS-3 datasets contain `campaign` information at the granule level within the Unified Metadata Model-Granule (UMM-G) [`AdditionalAttributes`](https://cmr.earthdata.nasa.gov/search/site/docs/search/api.html#c-additional-attribute)
# - For AVIRIS-3 L1B data, this next code block lists the campaigns and number of granules in each campaign
# - Note that at the time of writing this Notebook, this functionality is specific to AVIRIS-3 Datasets

# %%
def  get_campaign_names(granules):
    """get campaign names for all granules"""
    c = []
    for g in granules:
        for attrs in vars(g)['render_dict']['umm']['AdditionalAttributes']:
            if attrs['Name'] == 'Campaign':
                c += attrs['Values']
    return c

# earthdata search
granules = earthaccess.search_data(
    short_name = 'AV3_L1B_RDN_2356',
    #doi="10.3334/ORNLDAAC/2356"
)

campaigns = get_campaign_names(granules)

#print campaign names and granules
for name in list(set(campaigns)):
    print(f'{name} --> {campaigns.count(name)} granules')
# Out:
# Sacramento Delta --> 1030 granules
# FireSense --> 1281 granules
# WDTS --> 507 granules
# SHIFT --> 55 granules
# 2025 LA Fires --> 224 granules
# ABoVE --> 1405 granules
# GEMx --> 39 granules
# Calibration / Validation / Instrument Science / Testing --> 228 granules
# AiRMAPS --> 2572 granules
# Carbon Mapper --> 3919 granules
# GHG --> 1670 granules
# NEON --> 16 granules
# SCOAPE-II --> 625 granules
# DEVELOP Santa Clarita Valley Ecological Conservation --> 28 granules

# %% [markdown]
# If you know a NASA Project or Campaign employed the AVIRIS-3 instrument, you can directly query the `AdditionalAttributes`

# %%
#doi="10.3334/ORNLDAAC/2356" # AV3_L1B_RDN_2356
short_name = "AV3_L1B_RDN_2356"
query = earthaccess.DataGranules().short_name(short_name)
query.params['attribute[]'] = 'string,Campaign,SHIFT' 
l1b = query.get_all()
print(f'Granules found: {len(l1b)}')
# Out:
# Granules found: 55

# %%
print(l1b[0])
# Out:
# Collection: {'ShortName': 'AV3_L1B_RDN_2356', 'Version': '1'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -120.22971888002964, 'Latitude': 34.788751413589104}, {'Longitude': -120.23086813730406, 'Latitude': 34.75437988300693}, {'Longitude': -120.18983485544858, 'Latitude': 34.7534391621771}, {'Longitude': -120.1886686226504, 'Latitude': 34.78780949446484}, {'Longitude': -120.22971888002964, 'Latitude': 34.788751413589104}]}}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2024-08-26T18:04:21Z', 'EndingDateTime': '2024-08-26T18:04:45Z'}}
# Size(MB): 2105.9129781723022
# Data: ['https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AV3_L1B_RDN/data/AV320240826t180416_000_L1B_RDN_f6524bfe_RDN.nc', 'https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AV3_L1B_RDN/data/AV320240826t180416_000_L1B_ORT_55901fd4_OBS.nc', 'https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AV3_L1B_RDN/data/AV320240826t180416_000_L1B_RDN_f6524bfe_BANDMASK.nc', 'https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AV3_L1B_RDN/data/AV320240826t180416_000_L1B_RDN_f6524bfe_RDN_QL.tif', 'https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AV3_L1B_RDN/data/AV320240826t180416_000_L1B_RDN_f6524bfe.yaml', 'https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AV3_L1B_RDN/data/AV320240826t180416_000_L1B_ORT_55901fd4.yaml']

# %% [markdown]
# ## Setting Search Parameters for Granules

# %% [markdown]
# We'll use a NEON AOP Flight Boundary to search for AVIRIS data in a spatial area of interest.
#
# NEON AOP Flight Boundaries
# [https://hub.arcgis.com/datasets/f27616de7f9f401b8732cdf8902ab1d8/about]

# %%
# read the AVIRIS-NG_flights.shp file and convert to geojson using geopandas
AOP_polys = gpd.read_file('data/AOP_Flightboxes.shp')
AOP_polys.to_file('aop_json.geojson', driver='GeoJSON')

# %%
gdf = gpd.read_file('aop_json.geojson')

# Access the CRS using the .crs attribute
if gdf.crs:
    print(f"CRS: {gdf.crs}")
# Out:
# CRS: EPSG:4326

# %%
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92b91ec68e8bb885d0263e6811516d14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92b91ec68e8bb885d0263e6811516d14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92b91ec68e8bb885d0263e6811516d14 = L.map(
#                 &quot;map_92b91ec68e8bb885d0263e6811516d14&quot;,
#                 {
#                     center: [44.66717401998591, -111.8053408747864],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_92b91ec68e8bb885d0263e6811516d14);
#
#
#
#
#
#             var tile_layer_508a48b25e47b91696b55bad2f33955a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_508a48b25e47b91696b55bad2f33955a.addTo(map_92b91ec68e8bb885d0263e6811516d14);
#
#
#             map_92b91ec68e8bb885d0263e6811516d14.fitBounds(
#                 [[17.93711476179209, -156.84288639182745], [71.39723327817973, -66.76779535774534]],
#                 {}
#             );
#
#
#         function geo_json_f9c8ce3280667e56dd0457a921fb6306_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f9c8ce3280667e56dd0457a921fb6306_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f9c8ce3280667e56dd0457a921fb6306_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_f9c8ce3280667e56dd0457a921fb6306_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f9c8ce3280667e56dd0457a921fb6306_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f9c8ce3280667e56dd0457a921fb6306.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f9c8ce3280667e56dd0457a921fb6306_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f9c8ce3280667e56dd0457a921fb6306 = L.geoJson(null, {
#                 onEachFeature: geo_json_f9c8ce3280667e56dd0457a921fb6306_onEachFeature,
#
#                 style: geo_json_f9c8ce3280667e56dd0457a921fb6306_styler,
#                 pointToLayer: geo_json_f9c8ce3280667e56dd0457a921fb6306_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_f9c8ce3280667e56dd0457a921fb6306_add (data) {
#             geo_json_f9c8ce3280667e56dd0457a921fb6306
#                 .addData(data);
#         }
#             geo_json_f9c8ce3280667e56dd0457a921fb6306_add({&quot;bbox&quot;: [-156.84288639182745, 17.93711476179209, -66.76779535774534, 71.39723327817973], &quot;features&quot;: [{&quot;bbox&quot;: [-71.33425601207091, 43.99194755600888, -71.20949699774508, 44.08196459612299], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-71.33425601207091, 43.99196561902909], [-71.33423086233921, 44.08196459612299], [-71.20949699774508, 44.08194650792154], [-71.20952197030897, 43.99194755600888], [-

# %%
serc_aop = gdf[(gdf['siteID'] == 'SJER') & (gdf['priority'] == 1)]
#serc_aop = gdf[(gdf['siteID'] == 'BARR') & (gdf['priority'] == 1)]

# %%
 print(serc_aop.head())
# Out:
#    domain         domainName                             siteName siteID  \
# 60    D17  Pacific Southwest  San Joaquin Experimental Range NEON   SJER
#
#    siteType   sampleType  priority  version         flightbxID  \
# 60     Core  Terrestrial         1        2  D17_SJER_C1_P1_v2
#
#                                                                                                                geometry
# 60  POLYGON ((-119.78852 37.04531, -119.78852 37.13542, -119.67604 37.13542, -119.67604 37.04531, -119.78852 37.04531))

# %%
serc_aop.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3462c99486cb87bdca94d291899a6fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3462c99486cb87bdca94d291899a6fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3462c99486cb87bdca94d291899a6fd = L.map(
#                 &quot;map_d3462c99486cb87bdca94d291899a6fd&quot;,
#                 {
#                     center: [37.09036279988189, -119.73227999950296],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d3462c99486cb87bdca94d291899a6fd);
#
#
#
#
#
#             var tile_layer_2e317512701691eb74519c98085bebfd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e317512701691eb74519c98085bebfd.addTo(map_d3462c99486cb87bdca94d291899a6fd);
#
#
#             map_d3462c99486cb87bdca94d291899a6fd.fitBounds(
#                 [[37.045309507636716, -119.78852218028226], [37.13541609212706, -119.67603781872367]],
#                 {}
#             );
#
#
#         function geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a = L.geoJson(null, {
#                 onEachFeature: geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a_onEachFeature,
#
#                 style: geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a_styler,
#                 pointToLayer: geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a_add (data) {
#             geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a
#                 .addData(data);
#         }
#             geo_json_5a91a8f4e9e4e1d5e55bd0a9e30d6b0a_add({&quot;bbox&quot;: [-119.78852218028226, 37.045309507636716, -119.67603781872367, 37.13541609212706], &quot;features&quot;: [{&quot;bbox&quot;: [-119.78852218028226, 37.045309507636716, -119.67603781872367, 37.13541609212706], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-119.78852218028226, 37.045309507636716], [-119.78852218028226, 37.13541609212706], [-119.67603781872367, 37.13541609212706], [-119.67603781872367, 37.045309

# %% [markdown]
# Use the NEON AOP Boundary file to search for AVIRIS-Classic L2 Reflectance data within that boundary

# %%
# bounding lon, lat as a list of tuples
bounds = serc_aop.geometry.apply(orient, args=(1,))
bounds
# simplifying the polygon to bypass the coordinates 
# limit of the CMR with a tolerance of .01 degrees
xy = bounds.simplify(0.01).get_coordinates()
print(xy)

date_range = ("2019-01-01", "2019-12-31")

results = earthaccess.search_data(
    short_name = 'AVIRIS-Classic_L2_Reflectance_2154',
    #short_name = 'ABoVE_Airborne_AVIRIS_NG_V3_2362',
    #short_name = 'AVIRIS-NG_L2_Reflectance_2110	',
    #short_name = 'AVIRIS-NG_L1B_radiance_2095',
    polygon=list(zip(xy.x, xy.y)),
    temporal = date_range
)
print(f"Total AVIRIS collections found: {len(results)}")
# Out:
#              x          y
# 60 -119.788522  37.045310
# 60 -119.676038  37.045310
# 60 -119.676038  37.135416
# 60 -119.788522  37.135416
# 60 -119.788522  37.045310
# Total AVIRIS collections found: 3

# %% [markdown]
# **For our search parameters, let's explore the granules found**
# - Let's look at the first result

# %%
results[:1]
# Out:
# [Collection: {'ShortName': 'AVIRIS-Classic_L2_Reflectance_2154', 'Version': '1'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -119.7805, 'Latitude': 36.6489}, {'Longitude': -119.5878, 'Latitude': 36.6533}, {'Longitude': -119.6413, 'Latitude': 38.191}, {'Longitude': -119.838, 'Latitude': 38.1864}, {'Longitude': -119.7805, 'Latitude': 36.6489}]}}]}}}
#  Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2019-10-01T18:01:00Z', 'EndingDateTime': '2019-10-01T18:51:00Z'}}
#  Size(MB): 11973.347121238708
#  Data: ['https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AVIRIS-Classic_L2_Reflectance/data/f191001t01p00r06_h2o_v1l1_img.bin', 'https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AVIRIS-Classic_L2_Reflectance/data/f191001t01p00r06_h2o_v1l1_img.hdr', 'https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AVIRIS-Classic_L2_Reflectance/data/f191001t01p00r06_corr_v1l1_img.hdr', 'https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AVIRIS-Classic_L2_Reflectance/data/f191001t01p00r06_corr_v1l1_img.bin']]

# %%
results[0]
# Out:
# Collection: {'ShortName': 'AVIRIS-Classic_L2_Reflectance_2154', 'Version': '1'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -119.7805, 'Latitude': 36.6489}, {'Longitude': -119.5878, 'Latitude': 36.6533}, {'Longitude': -119.6413, 'Latitude': 38.191}, {'Longitude': -119.838, 'Latitude': 38.1864}, {'Longitude': -119.7805, 'Latitude': 36.6489}]}}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2019-10-01T18:01:00Z', 'EndingDateTime': '2019-10-01T18:51:00Z'}}
# Size(MB): 11973.347121238708
# Data: ['https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AVIRIS-Classic_L2_Reflectance/data/f191001t01p00r06_h2o_v1l1_img.bin', 'https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AVIRIS-Classic_L2_Reflectance/data/f191001t01p00r06_h2o_v1l1_img.hdr', 'https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AVIRIS-Classic_L2_Reflectance/data/f191001t01p00r06_corr_v1l1_img.hdr', 'https://data.ornldaac.earthdata.nasa.gov/protected/aviris/AVIRIS-Classic_L2_Reflectance/data/f191001t01p00r06_corr_v1l1_img.bin']

# %% [markdown]
# **You can download these files directly to your local machine by clicking on any of the files**
# - We also see that these data are **Cloud Hosted:** True

# %% [markdown]
# ### Create and Visualize the **`Bounding Boxes`** of the subset of files

# %% [markdown]
# From each granule, we'll use the CMR `Geometry` information to create a plot of the AVIRIS-3 flight lines from our temporal and spatial subset
#
# Below, we define two functions to plot the search results over a basemap
# - Function 1:  converts UMM geometry to multipolygons
#   -- `UMM` stands for NASA's Unified Metadata Model
# - Function 2: converts the Polygon List [ ] to a **`geopandas`** dataframe

# %%
def convert_umm_geometry(gpoly):
    """converts UMM geometry to multipolygons"""
    multipolygons = []
    for gl in gpoly:
        ltln = gl["Boundary"]["Points"]
        points = [(p["Longitude"], p["Latitude"]) for p in ltln]
        multipolygons.append(Polygon(points))
    return MultiPolygon(multipolygons)

# %%
def convert_list_gdf(datag):
    """converts List[] to geopandas dataframe"""
    # create pandas dataframe from json
    df = pd.json_normalize([vars(granule)['render_dict'] for granule in datag])
    # keep only last string of the column names
    df.columns=df.columns.str.split('.').str[-1]
    # convert polygons to multipolygonal geometry
    df["geometry"] = df["GPolygons"].apply(convert_umm_geometry)
    # return geopandas dataframe
    return gpd.GeoDataFrame(df, geometry="geometry", crs="EPSG:4326")
    
subset_gdf = convert_list_gdf(results)
subset_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
#subset_gdf.explore()

subset_gdf = convert_list_gdf(results)
subset_gdf.drop('Version', axis=1, inplace=True)
subset_gdf.explore(fill=False, tiles='https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}', attr='Google')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef638fe97f46d9ba38d205deb1c5e09d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef638fe97f46d9ba38d205deb1c5e09d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef638fe97f46d9ba38d205deb1c5e09d = L.map(
#                 &quot;map_ef638fe97f46d9ba38d205deb1c5e09d&quot;,
#                 {
#                     center: [37.23205, -119.70925],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_ef638fe97f46d9ba38d205deb1c5e09d);
#
#
#
#
#
#             var tile_layer_ca3805b57bf978907c0ac784a3b5b2a1 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ca3805b57bf978907c0ac784a3b5b2a1.addTo(map_ef638fe97f46d9ba38d205deb1c5e09d);
#
#
#             map_ef638fe97f46d9ba38d205deb1c5e09d.fitBounds(
#                 [[36.2731, -119.9493], [38.191, -119.4692]],
#                 {}
#             );
#
#
#         function geo_json_6e0cc142ed11da85a457f416b6f21d70_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6e0cc142ed11da85a457f416b6f21d70_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6e0cc142ed11da85a457f416b6f21d70_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_6e0cc142ed11da85a457f416b6f21d70_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6e0cc142ed11da85a457f416b6f21d70_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_6e0cc142ed11da85a457f416b6f21d70.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6e0cc142ed11da85a457f416b6f21d70_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6e0cc142ed11da85a457f416b6f21d70 = L.geoJson(null, {
#                 onEachFeature: geo_json_6e0cc142ed11da85a457f416b6f21d70_onEachFeature,
#
#                 style: geo_json_6e0cc142ed11da85a457f416b6f21d70_styler,
#                 pointToLayer: geo_json_6e0cc142ed11da85a457f416b6f21d70_pointToLayer,
#             ...{
#   &quot;fill&quot;: false,
# }
#         });
#
#         function geo_json_6e0cc142ed11da85a457f416b6f21d70_add (data) {
#             geo_json_6e0cc142ed11da85a457f416b6f21d70
#                 .addData(data);
#         }
#             geo_json_6e0cc142ed11da85a457f416b6f21d70_add({&quot;bbox&quot;: [-119.9493, 36.2731, -119.4692, 38.191], &quot;features&quot;: [{&quot;bbox&quot;: [-119.838, 36.6489, -119.5878, 38.191], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-119.7805, 36.6489], [-119.5878, 36.6533], [-119.6413, 38.191], [-119.838, 38.1864], [-119.7805, 36.6489]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;AdditionalAttributes&quot;: &quot;[{\u0027Name\u0027: \u0027Identifier_product_doi_authority\u0027, \u0027Values\u0027: [\u0027https://doi.org\u0027]}, {\u0

# %%
#subset_gdf.explore()

subset_gdf = convert_list_gdf(results)
subset_gdf.drop('Version', axis=1, inplace=True)

# Create the base map with `serc_aop`
base_map = serc_aop.explore(
    color="red",  # Outline color for serc_aop features
    fill=False,   # No fill for serc_aop
    legend=True,  # Display legend for serc_aop
    tiles='https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',  # Google Satellite tiles
    attr='Google'
)

# Add `subset_gdf` layer to the base map
final_map = subset_gdf.explore(
    color="blue",  # Outline color for subset_gdf features
    fill=False,    # No fill for subset_gdf
    legend=True,   # Display legend for subset_gdf
    m=base_map     # Add this layer to the base map
)

# Display the map
final_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a7c0e7f153c42456433cca8580d6fd4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a7c0e7f153c42456433cca8580d6fd4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a7c0e7f153c42456433cca8580d6fd4 = L.map(
#                 &quot;map_2a7c0e7f153c42456433cca8580d6fd4&quot;,
#                 {
#                     center: [37.09036279988189, -119.73227999950296],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_2a7c0e7f153c42456433cca8580d6fd4);
#
#
#
#
#
#             var tile_layer_88f4f75d6efde99aed9851867ab5ae6e = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=s\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_88f4f75d6efde99aed9851867ab5ae6e.addTo(map_2a7c0e7f153c42456433cca8580d6fd4);
#
#
#             map_2a7c0e7f153c42456433cca8580d6fd4.fitBounds(
#                 [[37.045309507636716, -119.78852218028226], [37.13541609212706, -119.67603781872367]],
#                 {}
#             );
#
#
#         function geo_json_da7c94efd422000d7b240ee1996e09ee_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_da7c94efd422000d7b240ee1996e09ee_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_da7c94efd422000d7b240ee1996e09ee_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_da7c94efd422000d7b240ee1996e09ee_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_da7c94efd422000d7b240ee1996e09ee_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_da7c94efd422000d7b240ee1996e09ee.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_da7c94efd422000d7b240ee1996e09ee_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_da7c94efd422000d7b240ee1996e09ee = L.geoJson(null, {
#                 onEachFeature: geo_json_da7c94efd422000d7b240ee1996e09ee_onEachFeature,
#
#                 style: geo_json_da7c94efd422000d7b240ee1996e09ee_styler,
#                 pointToLayer: geo_json_da7c94efd422000d7b240ee1996e09ee_pointToLayer,
#             ...{
#   &quot;fill&quot;: false,
# }
#         });
#
#         function geo_json_da7c94efd422000d7b240ee1996e09ee_add (data) {
#             geo_json_da7c94efd422000d7b240e
